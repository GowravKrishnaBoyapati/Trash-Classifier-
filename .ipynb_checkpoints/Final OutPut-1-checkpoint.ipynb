# %% [markdown]
# # **Import libraries**

# %%
import fastai
from fastai.vision.all import *
from pathlib import Path
import pandas as pd
import numpy as np

# %%
model=load_learner('./models/model.pkl')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-2-1947f38b5f84> in <module>
# ----> 1 model=load_learner('./models/model.pkl')
#
# c:\users\gowra\appdata\local\programs\python\python36\lib\site-packages\fastai\learner.py in load_learner(fname, cpu, pickle_module)
#     379     "Load a `Learner` object in `fname`, optionally putting it on the `cpu`"
#     380     distrib_barrier()
# --> 381     res = torch.load(fname, map_location='cpu' if cpu else None, pickle_module=pickle_module)
#     382     if hasattr(res, 'to_fp32'): res = res.to_fp32()
#     383     if cpu: res.dls.cpu()
#
# c:\users\gowra\appdata\local\programs\python\python36\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     590                     opened_file.seek(orig_position)
#     591                     return torch.jit.load(opened_file)
# --> 592                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     593         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     594
#
# c:\users\gowra\appdata\local\programs\python\python36\lib\site-packages\torch\serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#     849     unpickler = pickle_module.Unpickler(data_file, **pickle_load_args)
#     850     unpickler.persistent_load = persistent_load
# --> 851     result = unpickler.load()
#     852
#     853     torch._utils._validate_loaded_sparse_tensors()
#
# c:\users\gowra\appdata\local\programs\python\python36\lib\pathlib.py in __new__(cls, *args, **kwargs)
#    1002         if not self._flavour.is_supported:
#    1003             raise NotImplementedError("cannot instantiate %r on your system"
# -> 1004                                       % (cls.__name__,))
#    1005         self._init()
#    1006         return self
#
# NotImplementedError: cannot instantiate 'PosixPath' on your system

# %%
path = Path('./DATASET/')

# %%
images = path / 'TRAIN'

# %% [markdown]
# # **Creating a datablock and dataloader for train images**

# %%
db = DataBlock(blocks=(ImageBlock, CategoryBlock),
                   splitter=RandomSplitter(seed=42),
                   get_items=get_image_files, 
                   get_y=parent_label,
                   item_tfms=Resize(256))

# %%
dl = db.dataloaders(images)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
dl.show_batch(nrows=3, ncols=3)

# %% [markdown]
# # **Training**

# %% [markdown]
# First let's create a basic cnn model with fastai

# %%
model = cnn_learner(dl, resnet34, metrics=error_rate)
model.fine_tune(1, base_lr=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.447539</td>
#       <td>1.571262</td>
#       <td>0.212323</td>
#       <td>02:48</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.329366</td>
#       <td>0.313338</td>
#       <td>0.098183</td>
#       <td>02:54</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.lr_find()
# Out:
# SuggestedLRs(lr_min=9.12010818865383e-08, lr_steep=6.918309736647643e-06)

# %% [markdown]
# Now let's train a model specifying the suitable learning rate

# %%
model = cnn_learner(dl, resnet34, metrics=error_rate)
model.fine_tune(1, base_lr=2e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.276926</td>
#       <td>0.161937</td>
#       <td>0.060949</td>
#       <td>02:34</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.130570</td>
#       <td>0.102407</td>
#       <td>0.039229</td>
#       <td>03:11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We've got a better error rate! Now let's train the final model and see if results improve a bit more. First, the model trains on randomly added layers for one epoch, with all other layers frozen. Then it unfreezes all the layers and  trains with *discriminative learning rates*.

# %%
model = cnn_learner(dl, resnet34, metrics=error_rate)
model.fit_one_cycle(1, 2e-3)
model.unfreeze()
model.fit_one_cycle(8, lr_max=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.183014</td>
#       <td>0.121687</td>
#       <td>0.043661</td>
#       <td>02:21</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.160559</td>
#       <td>0.115370</td>
#       <td>0.042110</td>
#       <td>02:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.138263</td>
#       <td>0.107332</td>
#       <td>0.038342</td>
#       <td>03:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.110457</td>
#       <td>0.103948</td>
#       <td>0.036569</td>
#       <td>02:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.076225</td>
#       <td>0.105127</td>
#       <td>0.036569</td>
#       <td>02:51</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.054847</td>
#       <td>0.104886</td>
#       <td>0.033910</td>
#       <td>02:52</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.042618</td>
#       <td>0.105265</td>
#       <td>0.034796</td>
#       <td>02:55</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.039474</td>
#       <td>0.106467</td>
#       <td>0.033910</td>
#       <td>02:50</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.036133</td>
#       <td>0.106245</td>
#       <td>0.033910</td>
#       <td>02:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.recorder.plot_loss()

# %%
model.show_results()

# %%
interp = ClassificationInterpretation.from_learner(model)

# %%
interp.print_classification_report()
# Out:
#               precision    recall  f1-score   support
#
#            O       0.97      0.97      0.97      2509
#            R       0.96      0.96      0.96      2003
#
#     accuracy                           0.97      4512
#    macro avg       0.97      0.97      0.97      4512
# weighted avg       0.97      0.97      0.97      4512

# %%
interp.plot_confusion_matrix(figsize=(9,7), dpi=60)

# %%
interp.plot_top_losses(7, figsize=(15,11))

# %% [markdown]
# # **Model performance on test set**

# %%
test = path/'TEST'
test.ls()
# Out:
# (#2) [Path('DATASET/TEST/O'),Path('DATASET/TEST/R')]

# %%
test_images = get_image_files(test)

# %%
test_db = DataBlock(blocks=(ImageBlock, CategoryBlock),
                   get_items=get_image_files,
                  get_y=parent_label,
                   item_tfms=Resize(256))

# %%
test_dl = test_db.dataloaders(test)
# Out:
# Due to IPython and Windows limitation, python multiprocessing isn't available now.
# So `number_workers` is changed to 0 to avoid getting stuck

# %%
tdl = test_dl.test_dl(test_images, with_labels=False)

# %%
tdl.show_batch(nrows=3, ncols=3)

# %%
preds = model.get_preds(dl=tdl)

# %%
predictions = torch.argmax(preds[0], dim=1)
test_labels = torch.Tensor([1 if i.name[0] == 'R' else 0 for i in test_images])
accuracy = round((test_labels == predictions).float().mean().item()*100,1)
print(f'Accuracy on test set {accuracy}%')
# Out:
# Accuracy on test set 44.4%
